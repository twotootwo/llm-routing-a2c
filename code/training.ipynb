# %% [markdown]
# ### Check GPU

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %% [markdown]
# ### Mount google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Once Google Drive is mounted, please specify the path to the directory containing your file. For example, if your file is at `/content/drive/MyDrive/my_folder/my_file.txt`, then the path would be `/content/drive/MyDrive/my_folder`.

# %%
import os

directory_path = '/content/drive/MyDrive/Colab Notebooks/강화학습 프로젝트'
os.chdir(directory_path)

print(f'Current working directory changed to: {os.getcwd()}')
# Out:
# Current working directory changed to: /content/drive/MyDrive/Colab Notebooks/강화학습 프로젝트

# %%
# !ls
# Out:
# environment.yml		   lm+qa	       squad_dataset.py
# evaluate_change_models.py  lm_qa_dataset.py    state_features.py
# evaluate_model.py	   __pycache__	       train_a2c_change.py
# evaluate_models.py	   qa_env.py	       train_a2c.py
# evaluate_v1.py		   qa_span_wrapper.py  training.ipynb
# korquad_dataset.py	   routing_config.py
# llm_wrapper.py		   run_example.py

# %% [markdown]
# ###Installing dependencies

# %%
# 라이브러리 설치 셀
# !pip install -q \
  torch==2.2.2 torchvision==0.17.2 \
  transformers==4.44.2 \
  accelerate==0.33.0 \
  datasets==2.21.0 \
  sentencepiece \
  matplotlib  \
  "numpy>=1.24.0"
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 114.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 126.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.1/315.1 kB 32.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 47.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 135.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 101.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 61.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# ##Hyperparmeters (default)
# * ### w_retry = 0.2
# * ### w_token = 0.01
# * ### w_strong = 0.7
# * ### num_episodes = 500
# * ### learning_rate = 1e-3
# * ### gamma (discount factor) = 0.99
# * ### max_grad_norm = 0.5
# * ### value_loss_coef = 0.5
# * ### entropy_coef = 0.01

# %% [markdown]
# ### Training actor critic

# %%
# !python train_a2c.py
# Out:
# [Dataset] QA (SQuAD) for split=train: 87599 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
# [Episode 5/500] avg_reward=0.313, avg_F1(last_5)=0.473, global_avg_F1=0.473, last_reward=0.162, last_F1=0.962, action_dist(A/R/E)=0.67/0.17/0.17
# 📦 Saved checkpoint at episode 10 -> lm+qa/checkpoint/a2c_actor_critic_ep10.pt
# [Episode 10/500] avg_reward=0.005, avg_F1(last_5)=0.225, global_avg_F1=0.349, last_reward=0.035, last_F1=0.035, action_dist(A/R/E)=0.44/0.44/0.11
# ...

# %% [markdown]
# ### Evaluating multiple models

# %%
# !python evaluate_models.py
# Out:
# Eval device (policy net): cuda
# ...
# Generating train split: 100% 87599/87599 [00:00<00:00, 431622.90 examples/s]
# Generating validation split: 100% 10570/10570 [00:00<00:00, 480843.74 examples/s]
# [Dataset] QA (SQuAD) for split=validation: 10570 samples
# tokenizer_config.json: 7.30kB [00:00, 34.9MB/s]
# vocab.json: 2.78MB [00:00, 116MB/s]
# merges.txt: 1.67MB [00:00, 138MB/s]
# tokenizer.json: 7.03MB [00:00, 182MB/s]
# config.json: 100% 659/659 [00:00<00:00, 6.37MB/s]
# model.safetensors: 100% 988M/988M [00:04<00:00, 232MB/s]
# generation_config.json: 100% 242/242 [00:00<00:00, 2.60MB/s]
# tokenizer_config.json: 1.19kB [00:00, 8.72MB/s]
# config.json: 100% 696/696 [00:00<00:00, 7.62MB/s]
# vocab.json: 798kB [00:00, 115MB/s]
# merges.txt: 456kB [00:00, 117MB/s]
# special_tokens_map.json: 100% 239/239 [00:00<00:00, 2.79MB/s]
# ...

# %% [markdown]
# ## Base Model (default setting)

# %%
# !python train_a2c.py --lr 1e-3
# Out:
# [Dataset] QA (SQuAD) for split=train: 87599 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
# [Episode 5/500] avg_reward=0.307, avg_F1(last_5)=0.473, global_avg_F1=0.473, last_reward=0.152, last_F1=0.962, action_dist(A/R/E)=0.67/0.17/0.17
# 📦 Saved checkpoint at episode 10 -> lm+qa/checkpoint/a2c_actor_critic_ep10.pt
# [Episode 10/500] avg_reward=-0.003, avg_F1(last_5)=0.225, global_avg_F1=0.349, last_reward=0.029, last_F1=0.035, action_dist(A/R/E)=0.44/0.44/0.11
# ...

# %%
# !python evaluate_models.py
# Out:
# Eval device (policy net): cuda
# [Dataset] QA (SQuAD) for split=validation: 10570 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
#
# === Evaluating baselines ===
# Always Cheap    -> reward=0.1674, F1=0.1725, tokens=262.5, action_dist(A/R/E)=1.00/0.00/0.00
# Always Escalate -> reward=0.2238, F1=0.9314, tokens=406.2, action_dist(A/R/E)=0.00/0.00/1.00
# Random          -> reward=0.2007, F1=0.5501, tokens=335.5, action_dist(A/R/E)=0.51/0.00/0.49
#
# === Evaluating trained A2C checkpoints ===
# ...

# %% [markdown]
# ## Changing learning rate

# %% [markdown]
# ### Training learning_rate (1e-4)

# %%
# !python train_a2c.py --lr 1e-4
# Out:
# [Dataset] QA (SQuAD) for split=train: 87599 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
# [Episode 5/500] avg_reward=0.307, avg_F1(last_5)=0.473, global_avg_F1=0.473, last_reward=0.152, last_F1=0.962, action_dist(A/R/E)=0.67/0.17/0.17
# 📦 Saved checkpoint at episode 10 -> lm+qa/checkpoint/a2c_actor_critic_ep10.pt
# [Episode 10/500] avg_reward=-0.003, avg_F1(last_5)=0.225, global_avg_F1=0.349, last_reward=0.029, last_F1=0.035, action_dist(A/R/E)=0.44/0.44/0.11
# ...

# %%
# !python evaluate_models.py
# Out:
# Eval device (policy net): cuda
# ...
# Generating train split: 100% 87599/87599 [00:00<00:00, 395145.37 examples/s]
# Generating validation split: 100% 10570/10570 [00:00<00:00, 473449.31 examples/s]
# [Dataset] QA (SQuAD) for split=validation: 10570 samples
# tokenizer_config.json: 7.30kB [00:00, 12.8MB/s]
# vocab.json: 2.78MB [00:00, 149MB/s]
# merges.txt: 1.67MB [00:00, 131MB/s]
# tokenizer.json: 7.03MB [00:00, 180MB/s]
# config.json: 100% 659/659 [00:00<00:00, 7.07MB/s]
# model.safetensors: 100% 988M/988M [00:04<00:00, 220MB/s]
# generation_config.json: 100% 242/242 [00:00<00:00, 1.61MB/s]
# tokenizer_config.json: 1.19kB [00:00, 6.72MB/s]
# config.json: 100% 696/696 [00:00<00:00, 7.45MB/s]
# vocab.json: 798kB [00:00, 128MB/s]
# merges.txt: 456kB [00:00, 116MB/s]
# special_tokens_map.json: 100% 239/239 [00:00<00:00, 2.89MB/s]
# ...

# %% [markdown]
# ### Training learning rate(1e-5)

# %%
# !python train_a2c.py --lr 1e-5
# Out:
# [Dataset] QA (SQuAD) for split=train: 87599 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
# [Episode 5/500] avg_reward=0.307, avg_F1(last_5)=0.473, global_avg_F1=0.473, last_reward=0.152, last_F1=0.962, action_dist(A/R/E)=0.67/0.17/0.17
# 📦 Saved checkpoint at episode 10 -> lm+qa/checkpoint/a2c_actor_critic_ep10.pt
# [Episode 10/500] avg_reward=-0.003, avg_F1(last_5)=0.225, global_avg_F1=0.349, last_reward=0.029, last_F1=0.035, action_dist(A/R/E)=0.44/0.44/0.11
# ...

# %%
# !python evaluate_models.py
# Out:
# Eval device (policy net): cuda
# [Dataset] QA (SQuAD) for split=validation: 10570 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
#
# === Evaluating baselines ===
# Always Cheap    -> reward=0.1674, F1=0.1725, tokens=262.5, action_dist(A/R/E)=1.00/0.00/0.00
# Always Escalate -> reward=0.2238, F1=0.9314, tokens=406.2, action_dist(A/R/E)=0.00/0.00/1.00
# Random          -> reward=0.2007, F1=0.5501, tokens=335.5, action_dist(A/R/E)=0.51/0.00/0.49
#
# === Evaluating trained A2C checkpoints ===
# ...

# %% [markdown]
# ## Changing gamma

# %% [markdown]
# ### gamma 0.9

# %%
# !python train_a2c.py --gamma 0.9
# Out:
# [Dataset] QA (SQuAD) for split=train: 87599 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
# [Episode 5/500] avg_reward=0.307, avg_F1(last_5)=0.473, global_avg_F1=0.473, last_reward=0.152, last_F1=0.962, action_dist(A/R/E)=0.67/0.17/0.17
# 📦 Saved checkpoint at episode 10 -> lm+qa/checkpoint/a2c_actor_critic_ep10.pt
# [Episode 10/500] avg_reward=-0.003, avg_F1(last_5)=0.225, global_avg_F1=0.349, last_reward=0.029, last_F1=0.035, action_dist(A/R/E)=0.44/0.44/0.11
# ...

# %%
# !python evaluate_models.py
# Out:
# Eval device (policy net): cuda
# [Dataset] QA (SQuAD) for split=validation: 10570 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
#
# === Evaluating baselines ===
# Always Cheap    -> reward=0.1674, F1=0.1725, tokens=262.5, action_dist(A/R/E)=1.00/0.00/0.00
# Always Escalate -> reward=0.2238, F1=0.9314, tokens=406.2, action_dist(A/R/E)=0.00/0.00/1.00
# Random          -> reward=0.2007, F1=0.5501, tokens=335.5, action_dist(A/R/E)=0.51/0.00/0.49
#
# === Evaluating trained A2C checkpoints ===
# ...

# %% [markdown]
# ### gamma 0.8

# %%
# !python train_a2c.py --gamma 0.8
# Out:
# [Dataset] QA (SQuAD) for split=train: 87599 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
# [Episode 5/500] avg_reward=0.307, avg_F1(last_5)=0.473, global_avg_F1=0.473, last_reward=0.152, last_F1=0.962, action_dist(A/R/E)=0.67/0.17/0.17
# 📦 Saved checkpoint at episode 10 -> lm+qa/checkpoint/a2c_actor_critic_ep10.pt
# [Episode 10/500] avg_reward=-0.003, avg_F1(last_5)=0.225, global_avg_F1=0.349, last_reward=0.029, last_F1=0.035, action_dist(A/R/E)=0.44/0.44/0.11
# ...

# %%
# !python evaluate_models.py
# Out:
# Eval device (policy net): cuda
# [Dataset] QA (SQuAD) for split=validation: 10570 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
#
# === Evaluating baselines ===
# Always Cheap    -> reward=0.1674, F1=0.1725, tokens=262.5, action_dist(A/R/E)=1.00/0.00/0.00
# Always Escalate -> reward=0.2238, F1=0.9314, tokens=406.2, action_dist(A/R/E)=0.00/0.00/1.00
# Random          -> reward=0.2007, F1=0.5501, tokens=335.5, action_dist(A/R/E)=0.51/0.00/0.49
#
# === Evaluating trained A2C checkpoints ===
# ...

# %% [markdown]
# ###gamma 0.85

# %%
# !python train_a2c.py --gamma 0.85
# Out:
# [Dataset] QA (SQuAD) for split=train: 87599 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
# [Episode 5/500] avg_reward=0.307, avg_F1(last_5)=0.473, global_avg_F1=0.473, last_reward=0.152, last_F1=0.962, action_dist(A/R/E)=0.67/0.17/0.17
# 📦 Saved checkpoint at episode 10 -> lm+qa/checkpoint/a2c_actor_critic_ep10.pt
# [Episode 10/500] avg_reward=-0.003, avg_F1(last_5)=0.225, global_avg_F1=0.349, last_reward=0.029, last_F1=0.035, action_dist(A/R/E)=0.44/0.44/0.11
# ...

# %%
# !python evaluate_models.py
# Out:
# Eval device (policy net): cuda
# [Dataset] QA (SQuAD) for split=validation: 10570 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
#
# === Evaluating baselines ===
# Always Cheap    -> reward=0.1674, F1=0.1725, tokens=262.5, action_dist(A/R/E)=1.00/0.00/0.00
# Always Escalate -> reward=0.2238, F1=0.9314, tokens=406.2, action_dist(A/R/E)=0.00/0.00/1.00
# Random          -> reward=0.2007, F1=0.5501, tokens=335.5, action_dist(A/R/E)=0.51/0.00/0.49
#
# === Evaluating trained A2C checkpoints ===
# ...

# %% [markdown]
# ## Changing Entropy coef

# %% [markdown]
# ###entrophy coef =0.05

# %%
# !python train_a2c.py --entropy_coef 0.05
# Out:
# [Dataset] QA (SQuAD) for split=train: 87599 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
# [Episode 5/500] avg_reward=0.307, avg_F1(last_5)=0.473, global_avg_F1=0.473, last_reward=0.152, last_F1=0.962, action_dist(A/R/E)=0.67/0.17/0.17
# 📦 Saved checkpoint at episode 10 -> lm+qa/checkpoint/a2c_actor_critic_ep10.pt
# [Episode 10/500] avg_reward=-0.003, avg_F1(last_5)=0.225, global_avg_F1=0.349, last_reward=0.029, last_F1=0.035, action_dist(A/R/E)=0.44/0.44/0.11
# ...

# %%
# !python evaluate_models.py
# Out:
# Eval device (policy net): cuda
# [Dataset] QA (SQuAD) for split=validation: 10570 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
#
# === Evaluating baselines ===
# Always Cheap    -> reward=0.1674, F1=0.1725, tokens=262.5, action_dist(A/R/E)=1.00/0.00/0.00
# Always Escalate -> reward=0.2238, F1=0.9314, tokens=406.2, action_dist(A/R/E)=0.00/0.00/1.00
# Random          -> reward=0.2007, F1=0.5501, tokens=335.5, action_dist(A/R/E)=0.51/0.00/0.49
#
# === Evaluating trained A2C checkpoints ===
# ...

# %% [markdown]
# ### entropy coef = 0.15

# %%
# !python train_a2c.py --entropy_coef 0.15
# Out:
# [Dataset] QA (SQuAD) for split=train: 87599 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
# [Episode 5/500] avg_reward=0.307, avg_F1(last_5)=0.473, global_avg_F1=0.473, last_reward=0.152, last_F1=0.962, action_dist(A/R/E)=0.67/0.17/0.17
# 📦 Saved checkpoint at episode 10 -> lm+qa/checkpoint/a2c_actor_critic_ep10.pt
# [Episode 10/500] avg_reward=-0.003, avg_F1(last_5)=0.225, global_avg_F1=0.349, last_reward=0.029, last_F1=0.035, action_dist(A/R/E)=0.44/0.44/0.11
# ...

# %%
# !python evaluate_models.py
# Out:
# Eval device (policy net): cuda
# [Dataset] QA (SQuAD) for split=validation: 10570 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
#
# === Evaluating baselines ===
# Always Cheap    -> reward=0.1674, F1=0.1725, tokens=262.5, action_dist(A/R/E)=1.00/0.00/0.00
# Always Escalate -> reward=0.2238, F1=0.9314, tokens=406.2, action_dist(A/R/E)=0.00/0.00/1.00
# Random          -> reward=0.2007, F1=0.5501, tokens=335.5, action_dist(A/R/E)=0.51/0.00/0.49
#
# === Evaluating trained A2C checkpoints ===
# ...

# %% [markdown]
# ### entrophy coef = 0.3

# %%
# !python train_a2c.py --entropy_coef 0.3
# Out:
# [Dataset] QA (SQuAD) for split=train: 87599 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
# [Episode 5/500] avg_reward=0.307, avg_F1(last_5)=0.473, global_avg_F1=0.473, last_reward=0.152, last_F1=0.962, action_dist(A/R/E)=0.67/0.17/0.17
# 📦 Saved checkpoint at episode 10 -> lm+qa/checkpoint/a2c_actor_critic_ep10.pt
# [Episode 10/500] avg_reward=-0.003, avg_F1(last_5)=0.225, global_avg_F1=0.349, last_reward=0.029, last_F1=0.035, action_dist(A/R/E)=0.44/0.44/0.11
# ...

# %%
# !python evaluate_models.py
# Out:
# Eval device (policy net): cuda
# [Dataset] QA (SQuAD) for split=validation: 10570 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
#
# === Evaluating baselines ===
# Always Cheap    -> reward=0.1674, F1=0.1725, tokens=262.5, action_dist(A/R/E)=1.00/0.00/0.00
# Always Escalate -> reward=0.2238, F1=0.9314, tokens=406.2, action_dist(A/R/E)=0.00/0.00/1.00
# Random          -> reward=0.2007, F1=0.5501, tokens=335.5, action_dist(A/R/E)=0.51/0.00/0.49
#
# === Evaluating trained A2C checkpoints ===
# ...

# %% [markdown]
# ## Changing w_strong

# %% [markdown]
# ### w_strong = 0.6

# %%
# !python train_a2c.py --w_strong 0.6
# Out:
# [Dataset] QA (SQuAD) for split=train: 87599 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
# [Episode 5/500] avg_reward=0.327, avg_F1(last_5)=0.473, global_avg_F1=0.473, last_reward=0.252, last_F1=0.962, action_dist(A/R/E)=0.67/0.17/0.17
# 📦 Saved checkpoint at episode 10 -> lm+qa/checkpoint/a2c_actor_critic_ep10.pt
# [Episode 10/500] avg_reward=0.017, avg_F1(last_5)=0.225, global_avg_F1=0.349, last_reward=0.029, last_F1=0.035, action_dist(A/R/E)=0.44/0.44/0.11
# ...

# %%
# !python evaluate_models.py
# Out:
# Eval device (policy net): cuda
# [Dataset] QA (SQuAD) for split=validation: 10570 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
#
# === Evaluating baselines ===
# Always Cheap    -> reward=0.1674, F1=0.1725, tokens=262.5, action_dist(A/R/E)=1.00/0.00/0.00
# Always Escalate -> reward=0.2238, F1=0.9314, tokens=406.2, action_dist(A/R/E)=0.00/0.00/1.00
# Random          -> reward=0.2007, F1=0.5501, tokens=335.5, action_dist(A/R/E)=0.51/0.00/0.49
#
# === Evaluating trained A2C checkpoints ===
# ...

# %% [markdown]
# ### w_strong =0.75

# %%
# !python train_a2c.py --w_strong 0.75
# Out:
# [Dataset] QA (SQuAD) for split=train: 87599 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
# [Episode 5/500] avg_reward=0.297, avg_F1(last_5)=0.473, global_avg_F1=0.473, last_reward=0.102, last_F1=0.962, action_dist(A/R/E)=0.67/0.17/0.17
# 📦 Saved checkpoint at episode 10 -> lm+qa/checkpoint/a2c_actor_critic_ep10.pt
# [Episode 10/500] avg_reward=-0.013, avg_F1(last_5)=0.225, global_avg_F1=0.349, last_reward=0.029, last_F1=0.035, action_dist(A/R/E)=0.44/0.44/0.11
# ...

# %%
# !python evaluate_models.py
# Out:
# Eval device (policy net): cuda
# [Dataset] QA (SQuAD) for split=validation: 10570 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
#
# === Evaluating baselines ===
# Always Cheap    -> reward=0.1674, F1=0.1725, tokens=262.5, action_dist(A/R/E)=1.00/0.00/0.00
# Always Escalate -> reward=0.2238, F1=0.9314, tokens=406.2, action_dist(A/R/E)=0.00/0.00/1.00
# Random          -> reward=0.2007, F1=0.5501, tokens=335.5, action_dist(A/R/E)=0.51/0.00/0.49
#
# === Evaluating trained A2C checkpoints ===
# ...

# %% [markdown]
# ### w_strong =0.8

# %%
# !python train_a2c.py --w_strong 0.8
# Out:
# [Dataset] QA (SQuAD) for split=train: 87599 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
# [Episode 5/500] avg_reward=0.287, avg_F1(last_5)=0.473, global_avg_F1=0.473, last_reward=0.052, last_F1=0.962, action_dist(A/R/E)=0.67/0.17/0.17
# 📦 Saved checkpoint at episode 10 -> lm+qa/checkpoint/a2c_actor_critic_ep10.pt
# [Episode 10/500] avg_reward=-0.023, avg_F1(last_5)=0.225, global_avg_F1=0.349, last_reward=0.029, last_F1=0.035, action_dist(A/R/E)=0.44/0.44/0.11
# ...

# %%
# !python evaluate_models.py
# Out:
# Eval device (policy net): cuda
# [Dataset] QA (SQuAD) for split=validation: 10570 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
#
# === Evaluating baselines ===
# Always Cheap    -> reward=0.1674, F1=0.1725, tokens=262.5, action_dist(A/R/E)=1.00/0.00/0.00
# Always Escalate -> reward=0.2238, F1=0.9314, tokens=406.2, action_dist(A/R/E)=0.00/0.00/1.00
# Random          -> reward=0.2007, F1=0.5501, tokens=335.5, action_dist(A/R/E)=0.51/0.00/0.49
#
# === Evaluating trained A2C checkpoints ===
# ...

# %% [markdown]
# ## Changing w_token

# %% [markdown]
# ###w_token=0.05

# %%
# !python train_a2c.py --w_token 0.05
# Out:
# [Dataset] QA (SQuAD) for split=train: 87599 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
# [Episode 5/500] avg_reward=0.286, avg_F1(last_5)=0.473, global_avg_F1=0.473, last_reward=0.112, last_F1=0.962, action_dist(A/R/E)=0.67/0.17/0.17
# 📦 Saved checkpoint at episode 10 -> lm+qa/checkpoint/a2c_actor_critic_ep10.pt
# [Episode 10/500] avg_reward=-0.038, avg_F1(last_5)=0.225, global_avg_F1=0.349, last_reward=0.005, last_F1=0.035, action_dist(A/R/E)=0.44/0.44/0.11
# ...

# %%
# !python evaluate_models.py
# Out:
# Eval device (policy net): cuda
# [Dataset] QA (SQuAD) for split=validation: 10570 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
#
# === Evaluating baselines ===
# Always Cheap    -> reward=0.1674, F1=0.1725, tokens=262.5, action_dist(A/R/E)=1.00/0.00/0.00
# Always Escalate -> reward=0.2238, F1=0.9314, tokens=406.2, action_dist(A/R/E)=0.00/0.00/1.00
# Random          -> reward=0.2007, F1=0.5501, tokens=335.5, action_dist(A/R/E)=0.51/0.00/0.49
#
# === Evaluating trained A2C checkpoints ===
# ...

# %% [markdown]
# ###w_token=0.1

# %%
# !python train_a2c.py --w_token 0.1
# Out:
# [Dataset] QA (SQuAD) for split=train: 87599 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
# [Episode 5/500] avg_reward=0.259, avg_F1(last_5)=0.473, global_avg_F1=0.473, last_reward=0.062, last_F1=0.962, action_dist(A/R/E)=0.67/0.17/0.17
# 📦 Saved checkpoint at episode 10 -> lm+qa/checkpoint/a2c_actor_critic_ep10.pt
# [Episode 10/500] avg_reward=-0.081, avg_F1(last_5)=0.225, global_avg_F1=0.349, last_reward=-0.025, last_F1=0.035, action_dist(A/R/E)=0.44/0.44/0.11
# ...

# %%
# !python evaluate_models.py
# Out:
# Eval device (policy net): cuda
# [Dataset] QA (SQuAD) for split=validation: 10570 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
#
# === Evaluating baselines ===
# Always Cheap    -> reward=0.1674, F1=0.1725, tokens=262.5, action_dist(A/R/E)=1.00/0.00/0.00
# Always Escalate -> reward=0.2238, F1=0.9314, tokens=406.2, action_dist(A/R/E)=0.00/0.00/1.00
# Random          -> reward=0.2007, F1=0.5501, tokens=335.5, action_dist(A/R/E)=0.51/0.00/0.49
#
# === Evaluating trained A2C checkpoints ===
# ...

# %% [markdown]
# ###w_token=0.2

# %%
# !python train_a2c.py --w_token 0.2
# Out:
# [Dataset] QA (SQuAD) for split=train: 87599 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
# [Episode 5/500] avg_reward=0.205, avg_F1(last_5)=0.473, global_avg_F1=0.473, last_reward=-0.038, last_F1=0.962, action_dist(A/R/E)=0.67/0.17/0.17
# 📦 Saved checkpoint at episode 10 -> lm+qa/checkpoint/a2c_actor_critic_ep10.pt
# [Episode 10/500] avg_reward=-0.167, avg_F1(last_5)=0.225, global_avg_F1=0.349, last_reward=-0.085, last_F1=0.035, action_dist(A/R/E)=0.44/0.44/0.11
# ...

# %%
# !python evaluate_models.py
# Out:
# Eval device (policy net): cuda
# [Dataset] QA (SQuAD) for split=validation: 10570 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
#
# === Evaluating baselines ===
# Always Cheap    -> reward=0.1674, F1=0.1725, tokens=262.5, action_dist(A/R/E)=1.00/0.00/0.00
# Always Escalate -> reward=0.2238, F1=0.9314, tokens=406.2, action_dist(A/R/E)=0.00/0.00/1.00
# Random          -> reward=0.2007, F1=0.5501, tokens=335.5, action_dist(A/R/E)=0.51/0.00/0.49
#
# === Evaluating trained A2C checkpoints ===
# ...

# %% [markdown]
# ##Changing w_retry

# %% [markdown]
# ###w_retry=0.1

# %%
# !python train_a2c.py --w_retry 0.1
# Out:
# [Dataset] QA (SQuAD) for split=train: 87599 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
# [Episode 5/500] avg_reward=0.317, avg_F1(last_5)=0.473, global_avg_F1=0.473, last_reward=0.202, last_F1=0.962, action_dist(A/R/E)=0.67/0.17/0.17
# 📦 Saved checkpoint at episode 10 -> lm+qa/checkpoint/a2c_actor_critic_ep10.pt
# [Episode 10/500] avg_reward=0.037, avg_F1(last_5)=0.225, global_avg_F1=0.349, last_reward=0.029, last_F1=0.035, action_dist(A/R/E)=0.44/0.44/0.11
# ...

# %%
# !python evaluate_models.py
# Out:
# Eval device (policy net): cuda
# [Dataset] QA (SQuAD) for split=validation: 10570 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
#
# === Evaluating baselines ===
# Always Cheap    -> reward=0.1674, F1=0.1725, tokens=262.5, action_dist(A/R/E)=1.00/0.00/0.00
# Always Escalate -> reward=0.2238, F1=0.9314, tokens=406.2, action_dist(A/R/E)=0.00/0.00/1.00
# Random          -> reward=0.2007, F1=0.5501, tokens=335.5, action_dist(A/R/E)=0.51/0.00/0.49
#
# === Evaluating trained A2C checkpoints ===
# ...

# %% [markdown]
# ###w_retry=0.05

# %%
# !python train_a2c.py --w_retry 0.05
# Out:
# [Dataset] QA (SQuAD) for split=train: 87599 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
# [Episode 5/500] avg_reward=0.322, avg_F1(last_5)=0.473, global_avg_F1=0.473, last_reward=0.227, last_F1=0.962, action_dist(A/R/E)=0.67/0.17/0.17
# 📦 Saved checkpoint at episode 10 -> lm+qa/checkpoint/a2c_actor_critic_ep10.pt
# [Episode 10/500] avg_reward=0.057, avg_F1(last_5)=0.225, global_avg_F1=0.349, last_reward=0.029, last_F1=0.035, action_dist(A/R/E)=0.44/0.44/0.11
# ...

# %%
# !python evaluate_models.py
# Out:
# Eval device (policy net): cuda
# [Dataset] QA (SQuAD) for split=validation: 10570 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
#
# === Evaluating baselines ===
# Always Cheap    -> reward=0.1674, F1=0.1725, tokens=262.5, action_dist(A/R/E)=1.00/0.00/0.00
# Always Escalate -> reward=0.2238, F1=0.9314, tokens=406.2, action_dist(A/R/E)=0.00/0.00/1.00
# Random          -> reward=0.2007, F1=0.5501, tokens=335.5, action_dist(A/R/E)=0.51/0.00/0.49
#
# === Evaluating trained A2C checkpoints ===
# ...

# %% [markdown]
# ###w_retry=0.01

# %%
# !python train_a2c.py --w_retry 0.01
# Out:
# [Dataset] QA (SQuAD) for split=train: 87599 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
# [Episode 5/500] avg_reward=0.326, avg_F1(last_5)=0.473, global_avg_F1=0.473, last_reward=0.247, last_F1=0.962, action_dist(A/R/E)=0.67/0.17/0.17
# 📦 Saved checkpoint at episode 10 -> lm+qa/checkpoint/a2c_actor_critic_ep10.pt
# [Episode 10/500] avg_reward=0.073, avg_F1(last_5)=0.225, global_avg_F1=0.349, last_reward=0.029, last_F1=0.035, action_dist(A/R/E)=0.44/0.44/0.11
# ...

# %%
# !python evaluate_models.py
# Out:
# Eval device (policy net): cuda
# [Dataset] QA (SQuAD) for split=validation: 10570 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
#
# === Evaluating baselines ===
# Always Cheap    -> reward=0.1674, F1=0.1725, tokens=262.5, action_dist(A/R/E)=1.00/0.00/0.00
# Always Escalate -> reward=0.2238, F1=0.9314, tokens=406.2, action_dist(A/R/E)=0.00/0.00/1.00
# Random          -> reward=0.2007, F1=0.5501, tokens=335.5, action_dist(A/R/E)=0.51/0.00/0.49
#
# === Evaluating trained A2C checkpoints ===
# ...

# %% [markdown]
# ##Changing num episodes

# %% [markdown]
# ### num_episodes 1000

# %%
# !python train_a2c.py --num_episodes 1000
# Out:
# [Dataset] QA (SQuAD) for split=train: 87599 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
# [Episode 5/1000] avg_reward=0.307, avg_F1(last_5)=0.473, global_avg_F1=0.473, last_reward=0.152, last_F1=0.962, action_dist(A/R/E)=0.67/0.17/0.17
# 📦 Saved checkpoint at episode 10 -> lm+qa/checkpoint/a2c_actor_critic_ep10.pt
# [Episode 10/1000] avg_reward=-0.003, avg_F1(last_5)=0.225, global_avg_F1=0.349, last_reward=0.029, last_F1=0.035, action_dist(A/R/E)=0.44/0.44/0.11
# ...

# %%
# !python evaluate_models.py
# Out:
# Eval device (policy net): cuda
# [Dataset] QA (SQuAD) for split=validation: 10570 samples
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Cheap model  : Qwen/Qwen2.5-0.5B-Instruct (type=lm, device=cuda)
# Strong model : deepset/roberta-large-squad2 (type=qa, device=cuda)
#
# === Evaluating baselines ===
# Always Cheap    -> reward=0.1674, F1=0.1725, tokens=262.5, action_dist(A/R/E)=1.00/0.00/0.00
# Always Escalate -> reward=0.2238, F1=0.9314, tokens=406.2, action_dist(A/R/E)=0.00/0.00/1.00
# Random          -> reward=0.2007, F1=0.5501, tokens=335.5, action_dist(A/R/E)=0.51/0.00/0.49
#
# === Evaluating trained A2C checkpoints ===
# ...

# %% [markdown]
# ### num_episodes 2000

# %%
# !python train_a2c.py --num_episodes 2000
# Out:
# ...
# Generating train split: 100% 87599/87599 [00:00<00:00, 459281.95 examples/s]
# Generating validation split: 100% 10570/10570 [00:00<00:00, 524505.10 examples/s]
# [Dataset] QA (SQuAD) for split=train: 87599 samples
# tokenizer_config.json: 7.30kB [00:00, 28.7MB/s]
# vocab.json: 2.78MB [00:00, 114MB/s]
# merges.txt: 1.67MB [00:00, 143MB/s]
# tokenizer.json: 7.03MB [00:00, 195MB/s]
# config.json: 100% 659/659 [00:00<00:00, 4.16MB/s]
# model.safetensors: 100% 988M/988M [00:06<00:00, 158MB/s]
# generation_config.json: 100% 242/242 [00:00<00:00, 1.45MB/s]
# tokenizer_config.json: 1.19kB [00:00, 8.59MB/s]
# config.json: 100% 696/696 [00:00<00:00, 8.82MB/s]
# vocab.json: 798kB [00:00, 147MB/s]
# merges.txt: 456kB [00:00, 119MB/s]
# special_tokens_map.json: 100% 239/239 [00:00<00:00, 3.00MB/s]
# ...

# %%
# !python evaluate_models.py

# %% [markdown]
# ## Training after ablation

# %%
# !python train_a2c.py --w_strong 0.75 --w_token 0.05 --gamma 0.9 --entropy_coef 0.05 --num_episodes 1000

# %%
# !python evaluate_models.py
